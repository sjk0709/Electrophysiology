# %%
from scipy.integrate import ode, solve_ivp
import os, time
import numpy as np
import matplotlib.pyplot as plt
import pickle
import bisect
from br1977_myokit import BR1977
# Out:
# WARNING:myokit._config:Sundials version not set in myokit.ini. Continuing with detected version (20700). For a tiny performance boost, please set this version in /root/.config/myokit/myokit.ini

# %%
if __name__=='__main__':
    
    start_time = time.time()
    
    model_path = "./mmt-model/br-1977.mmt"    
    model = BR1977(model_path) 
    times = np.arange(30)
    times = np.linspace(0,2000,5000)
    model.set_times(times)
    d = model.simulate(['engine.pace'], plot=True)    
    print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# Times has been set.
# --- 1.082096815109253 seconds ---

# %%
# plt.plot(d['engine.time'], d['engine.pace'])
# plt.show()
# print(d['engine.pace'])

# %%
print("finish")
# Out:
# finish
