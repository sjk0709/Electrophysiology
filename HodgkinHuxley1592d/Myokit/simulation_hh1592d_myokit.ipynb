# %%
from scipy.integrate import ode, solve_ivp
import os, time
import numpy as np
import matplotlib.pyplot as plt
import pickle
import bisect
from hh1592d_myokit import HH1592d
# Out:
# WARNING:myokit._config:Sundials version not set in myokit.ini. Continuing with detected version (20700). For a tiny performance boost, please set this version in /root/.config/myokit/myokit.ini

# %%
if __name__=='__main__':
    
    start_time = time.time()
    
    model_path = "./mmt-model/hh-1952d-modern.mmt"    
    hh = HH1592d(model_path) 
    times = np.arange(30)
    times = np.linspace(0,90,1000)
    hh.set_times(times)
    d = hh.simulate(['engine.pace'], plot=True)    
    print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# Times has been set.
# --- 1.232358455657959 seconds ---

# %%
# plt.plot(d['engine.time'], d['engine.pace'])
# plt.show()
# print(d['engine.pace'])

# %%
print("finish")
# Out:
# finish
