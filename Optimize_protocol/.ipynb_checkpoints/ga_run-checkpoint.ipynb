# %%
import sys, os
import copy
import time
import pickle

sys.path.append('../')
sys.path.append('../Lib')
sys.path.append('../Protocols')
import ga_configs
import ga_vc_optimization_JK
import myokit
import simulator_myokit
import vc_protocols

# %%
VCO_CONFIG = ga_configs.VoltageOptimizationConfig(
    window=10,
    step_size=5,
    steps_in_protocol=4,
    step_duration_bounds=(5, 1000),
    step_voltage_bounds=(-121, 61),
    target_current='',
    population_size=504,
    max_generations=101,
    mate_probability=0.9,
    mutate_probability=0.9,
    gene_swap_probability=0.2,
    gene_mutation_probability=0.1,
    tournament_size=2,
    step_types=['step', 'ramp'],
    with_artefact=False,    
    model_name='BR1977',  # OHara2017   Kernik       ORD2011
    mmt_file = "../mmt-model-files/ohara-cipa-v1-2017_VC.mmt" # if myokit model is used.
)

LIST_OF_CURRENTS = ['I_Na', 'I_si', 'I_K1', 'I_x1']

# %%
def main():
    """Run parameter tuning or voltage clamp protocol experiments here
    """
    results_dir = './ga_results'
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
        
    vco_dir_name = f'{VCO_CONFIG.model_name}_{VCO_CONFIG.population_size}_{VCO_CONFIG.max_generations}_{VCO_CONFIG.steps_in_protocol}_{VCO_CONFIG.step_voltage_bounds[0]}_{VCO_CONFIG.step_voltage_bounds[1]}_{VCO_CONFIG.window}_{VCO_CONFIG.step_size}'
    print(vco_dir_name)
    
    if not vco_dir_name in os.listdir('ga_results'):
        os.mkdir(f'ga_results/{vco_dir_name}')

    for c in LIST_OF_CURRENTS:
        f = f"{results_dir}/{vco_dir_name}/ga_results_{c}_a{VCO_CONFIG.with_artefact}"
        print(f"Finding best protocol for {c}. Writing protocol to: {f}")
        VCO_CONFIG.target_current = c
        result = ga_vc_optimization_JK.start_ga(VCO_CONFIG)
        print("="*100)
        pickle.dump(result, open(f, 'wb'))

# %%
if __name__ == '__main__':
    main()
    print("=====Complete==============================")
# Out:
# BR1977_504_101_4_-121_61_10_5
# Finding best protocol for I_Na. Writing protocol to: ./ga_results/BR1977_504_101_4_-121_61_10_5/ga_results_I_Na_aFalse
# 	Evaluating initial population.
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# JK--- 15.62588906288147 seconds ---
# 	Generation 1 for I_Na
# 		Min fitness: (0.18396238898575284,)
# 		Max fitness: (0.8927848216199661,)
# 		Average fitness: 0.7129945081963822
# 		Standard deviation: 0.11345947592967433
# 	Generation 2 for I_Na
# 		Min fitness: (0.2099855617471668,)
# 		Max fitness: (0.89289493388812,)
# 		Average fitness: 0.750658123215474
# 		Standard deviation: 0.11157990239625915
# 	Generation 3 for I_Na
# 		Min fitness: (0.12281294484627242,)
# 		Max fitness: (0.89289493388812,)
# 		Average fitness: 0.7863302736685777
# 		Standard deviation: 0.10112373640363365
# 	Generation 4 for I_Na
# 		Min fitness: (0.27341497362375433,)
# 		Max fitness: (0.8987564066217608,)
# 		Average fitness: 0.8140764434566843
# 		Standard deviation: 0.07820758144798677
# 	Generation 5 for I_Na
# 		Min fitness: (0.3503759977644742,)
# 		Max fitness: (0.911785742662383,)
# 		Average fitness: 0.8312118260332024
# 		Standard deviation: 0.07145645008261432
# 	Generation 6 for I_Na
# 		Min fitness: (0.10351724030151618,)
# 		Max fitness: (0.8987564066217608,)
# 		Average fitness: 0.8478366097434767
# 		Standard deviation: 0.07005573244328674
# 	Generation 7 for I_Na
# 		Min fitness: (0.29914549006867586,)
# 		Max fitness: (0.8987564066217608,)
# 		Average fitness: 0.8585305569439564
# 		Standard deviation: 0.0612683581056704
# 	Generation 8 for I_Na
# 		Min fitness: (0.10351724030151618,)
# 		Max fitness: (0.8995559189898242,)
# 		Average fitness: 0.8644087151485754
# 		Standard deviation: 0.06780973062791902
# 	Generation 9 for I_Na
# 		Min fitness: (0.511386174842524,)
# 		Max fitness: (0.9092888480205257,)
# 		Average fitness: 0.873189770901489
# 		Standard deviation: 0.04605227334931942
# 	Generation 10 for I_Na
# 		Min fitness: (0.22063253144741624,)
# 		Max fitness: (0.9092888480205257,)
# 		Average fitness: 0.8723605505594905
# 		Standard deviation: 0.06358771385989899
# 	Generation 11 for I_Na
# 		Min fitness: (0.31337893988720705,)
# 		Max fitness: (0.9092888480205257,)
# 		Average fitness: 0.8782929811312157
# 		Standard deviation: 0.05893015068545427
# 	Generation 12 for I_Na
# 		Min fitness: (0.30070938854847595,)
# 		Max fitness: (0.9012722979572856,)
# 		Average fitness: 0.8800778159519922
# 		Standard deviation: 0.05582242924345313
# 	Generation 13 for I_Na
# 		Min fitness: (0.2792375392973246,)
# 		Max fitness: (0.8991899046247855,)
# 		Average fitness: 0.8824260839662181
# 		Standard deviation: 0.06130031269363943
# 	Generation 14 for I_Na
# 		Min fitness: (0.4795029800349555,)
# 		Max fitness: (0.8993506649805433,)
# 		Average fitness: 0.8854441922254174
# 		Standard deviation: 0.043544310860176204
# 	Generation 15 for I_Na
# 		Min fitness: (0.4418284155766088,)
# 		Max fitness: (0.9055351576004411,)
# 		Average fitness: 0.8880381462506746
# 		Standard deviation: 0.03920714702983555
# 	Generation 16 for I_Na
# 		Min fitness: (0.6351657791987572,)
# 		Max fitness: (0.9055351576004411,)
# 		Average fitness: 0.89169290506128
# 		Standard deviation: 0.019850532833428566
# 	Generation 17 for I_Na
# 		Min fitness: (0.5620882474566121,)
# 		Max fitness: (0.9152653249101563,)
# 		Average fitness: 0.8921755614738686
# 		Standard deviation: 0.025627105315170935
# 	Generation 18 for I_Na
# 		Min fitness: (0.31262059716637997,)
# 		Max fitness: (0.9152653249101563,)
# 		Average fitness: 0.8868176038545715
# 		Standard deviation: 0.04656005881549274
# 	Generation 19 for I_Na
# 		Min fitness: (0.44615223987289193,)
# 		Max fitness: (0.9152653249101563,)
# 		Average fitness: 0.8893839628095844
# 		Standard deviation: 0.03845605263069582
# 	Generation 20 for I_Na
# 		Min fitness: (0.4540443087197317,)
# 		Max fitness: (0.9020411513498267,)
# 		Average fitness: 0.8894563490880968
# 		Standard deviation: 0.04395949430059168
# 	Generation 21 for I_Na
