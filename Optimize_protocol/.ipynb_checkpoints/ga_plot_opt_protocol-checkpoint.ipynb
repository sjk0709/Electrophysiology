# %%
import pickle
import sys, os
import matplotlib.pyplot as plt


sys.path.append('../Lib')
import mod_protocols as protocols
import mod_kernik as kernik


def plot_shorten_with_vcmd(trial_conditions, model_name, is_vc_only=False):
    path_to_data = f"ga_results/{trial_conditions}"

    files = os.listdir(path_to_data)

    for f in files:
        if ('shorten' in f) and ('pkl' in f):
            file_name = f
    print(f"{path_to_data}/{file_name}")
    short_protocol = pickle.load(open(f"{path_to_data}/{file_name}", 'rb'))
    print("="*50)
    print(short_protocol)
    print("="*50)
    print(f'The protocol is {short_protocol.get_voltage_change_endpoints()[-1]} ms')

    if is_vc_only:
        short_protocol.plot_voltage_clamp_protocol()
        return

# %%
def main():
    trial_conditions = "trial_steps_ramps_ORD2011_2_2_4_-120_60"
    if 'ORD2011' in trial_conditions:
        model_name = 'ORD2011'
    elif 'BR1977' in trial_conditions:
        model_name = 'BR1977'
    elif 'Kernik' in trial_conditions:
        model_name = 'Kernik'
    
    plot_shorten_with_vcmd(trial_conditions, model_name, is_vc_only=True)

# %%
if __name__ == '__main__':
    main()
    print("=====Complete==============================")
# Out:
# ga_results/trial_steps_ramps_BR1977_256_64_4_-120_60/shortened_trial_steps_ramps_BR1977_256_64_4_-120_60_500_artefact_True_short.pkl
# ==================================================
# |STEP: Voltage: -80, Duration: 500| | |STEP: Voltage: -30.254114894666618, Duration: 173.55560817495757| | |RAMP: Voltage Start: 23.33967220365725, Voltage End: -93.23276812434169, Duration: 389.6960487498407| | |RAMP: Voltage Start: -12.979890223338991, Voltage End: -34.19308198075669, Duration: 91.74834307520177| | |STEP: Voltage: -80, Duration: 500| | |STEP: Voltage: 12.448414108447098, Duration: 35.9945581567723| | |STEP: Voltage: -87.23504170623981, Duration: 99.0054418432277| | |STEP: Voltage: -80, Duration: 500| | |STEP: Voltage: -119.99902472787116, Duration: 30.0| | |STEP: Voltage: -80, Duration: 500| | |STEP: Voltage: 15.317808495449496, Duration: 286.1379790456223| | |STEP: Voltage: 22.8001275527836, Duration: 941.5982712362031| | |STEP: Voltage: 35.62859110956247, Duration: 948.2442865846083| | |RAMP: Voltage Start: -87.37630691117529, Voltage End: -70.56608774244593, Duration: 94.0194631335662|
# ==================================================
# The protocol is 5089.999999999999 ms

# %%
# Out:
# complete
