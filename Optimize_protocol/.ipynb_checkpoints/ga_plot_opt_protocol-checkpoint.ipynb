# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import pickle

sys.path.append('../Lib')
sys.path.append('../Protocols')
import protocol_lib
import mod_kernik as kernik

def plot_shorten_with_vcmd(trial_conditions, model_name, is_vc_only=False):
    path_to_data = f"ga_results/{trial_conditions}"

    files = os.listdir(path_to_data)

    for f in files:
        if ('shorten' in f) and ('pkl' in f):
            file_name = f
    print(f"{path_to_data}/{file_name}")
    short_protocol = pickle.load(open(f"{path_to_data}/{file_name}", 'rb'))
    print("="*50)
    print(short_protocol)
    print("="*50)
    print(f'The protocol is {short_protocol.get_voltage_change_endpoints()[-1]} ms')

    if is_vc_only:
        times = np.arange(0, short_protocol.get_voltage_change_endpoints()[-1], 0.5)         
        print(times.shape)
        short_protocol.plot_voltage_clamp_protocol(times)
        return
# Out:
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
def main():
    trial_conditions = "trial_steps_ramps_ORD2011_288_51_4_-121_61"
    if 'ORD2011' in trial_conditions:
        model_name = 'ORD2011'
    elif 'OHara2017' in trial_conditions:
        model_name = 'OHara2017'
    elif 'BR1977' in trial_conditions:
        model_name = 'BR1977'
    elif 'Kernik' in trial_conditions:
        model_name = 'Kernik'
    
    plot_shorten_with_vcmd(trial_conditions, model_name, is_vc_only=True)

# %%
if __name__ == '__main__':
    main()
    print("=====Complete==============================")
# Out:
# ga_results/trial_steps_ramps_ORD2011_288_51_4_-121_61/shortened_trial_steps_ramps_ORD2011_288_51_4_-121_61_500_artefact_False_short.pkl
# ==================================================
# |STEP: Voltage: -80, Duration: 500| + |RAMP: Voltage Start: -58.49015286068326, Voltage End: -113.96608561075345, Duration: 59.95252225041901| + |RAMP: Voltage Start: -34.9671903327344, Voltage End: 41.237066608083424, Duration: 99.59121016877876| + |RAMP: Voltage Start: -31.78415487229718, Voltage End: -31.802218693131454, Duration: 0.45626758080231866| + |STEP: Voltage: -80, Duration: 500| + |STEP: Voltage: -120.6344015725005, Duration: 70.35243428122453| + |STEP: Voltage: -120.87421944716017, Duration: 793.1991111789367| + |RAMP: Voltage Start: -2.7713276542567864, Voltage End: -74.84213289644316, Duration: 112.79607720327556| + |STEP: Voltage: -80, Duration: 500| + |STEP: Voltage: -65.54247754948985, Duration: 149.2852608248462| + |STEP: Voltage: 60.89878539050991, Duration: 100.7147391751538| + |STEP: Voltage: -80, Duration: 500| + |RAMP: Voltage Start: -28.798976339972207, Voltage End: -29.762700620908646, Duration: 130.55804944192505| + |STEP: Voltage: -28.957941546931057, Duration: 963.3792209240725| + |STEP: Voltage: 0.6112568316497514, Duration: 101.06272963400261| + |STEP: Voltage: -80, Duration: 500| + |RAMP: Voltage Start: -50.54675672988333, Voltage End: -39.00427836784277, Duration: 538.6620737370066| + |RAMP: Voltage Start: 60.79504462374705, Voltage End: -111.35154599817501, Duration: 193.41155378392398| + |STEP: Voltage: -80, Duration: 500| + |STEP: Voltage: 55.841025567486014, Duration: 778.0961575699066| + |STEP: Voltage: -110.78724662808052, Duration: 215.98659268860592| + |STEP: Voltage: 52.420827824481165, Duration: 803.4812400961757| + |STEP: Voltage: -87.90281464332278, Duration: 107.43600964531174| + |STEP: Voltage: -80, Duration: 500| + |STEP: Voltage: -101.31965783015615, Duration: 96.96159319519165| + |STEP: Voltage: -120.99354601482024, Duration: 103.03840680480835|
# ==================================================
# The protocol is 8918.421250184369 ms
# (17837,)
# =====Complete==============================
