# %%
from scipy.integrate import ode, solve_ivp
import os, sys, time
import numpy as np
import matplotlib.pyplot as plt
import pickle
import bisect

from simulator_myokit import Simulator
sys.path.append('../')
import plot_cell
# Out:
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
sys.path.append('./Protocols')
from protocols import optimized_VC_Christini
'''
New O'Hara-Rudy model with VC
'''
model_path = "./mmt-model-files/newordherg_qNet_VC.mmt" 
sim_params = {
    'cell.mode': 1,         # 'Endocardial' : 0,    'Epicardial' : 1,    'Mid-myocardial' : 2,
    'ina.GNafc' : 1,
    'inal.GNaLfc' : 1,
    'ito.Gtofc' : 1,
    'ical.PCafc' : 1,
    'ikr.GKrfc' : 1,
    'iks.GKsfc' : 1,
    'ik1.GK1fc' : 1,
    'if.Gffc' : 1    
} 
G_li = ['ina.GNa', 'inal.GNaL', 'ito.Gto', 'ical.PCa', 'ikr.GKr', 'iks.GKs', 'ik1.GK1', 'if.Gf']
I_li = ['ina.INa', 'inal.INaL', 'ito.Ito', 'ical.ICaL', 'ikr.IKr', 'iks.IKs', 'ik1.IK1', 'if.iF']   

start_time = time.time()
simulator = Simulator(model_path, optimized_VC_Christini, vhold=-80e-3) 
simulator.name = "New O'Hara-Rudy model with VC"
Gs = [simulator.model.get(G).value() for G in G_li]
times = np.arange(0, simulator.protocol_total_duration, 1)# np.linspace(0, simulator.total_duration, 20000)  
simulator.pacing_constant_pre_simulate(-80e-3)
simulator.set_simulation_params(sim_params)
d = simulator.simulate(times, extra_log=I_li, pre_sim=2)        
plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=simulator.name, figsize=(6,4))
textstr = "GNa : %1.4f\nGNaL : %1.4f\nGto : %1.4f\nPCa : %1.4f\nGKr : %1.4f\nGKs : %1.4f\nGK1 : %1.4f\nGf : %1.4f"%(Gs[0], Gs[1], Gs[2], Gs[3], Gs[4], Gs[5], Gs[6], Gs[7])
plot_cell.plot_1D_multi( d['engine.time'], [d[x] for x in extra_log], labels=[I.split('.')[1] for I in I_li], title=simulator.name, figsize=(6,4), textstr=textstr)
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# ./Protocols/trial_steps_ramps_Kernik_200_50_4_-120_60/shortened_trial_steps_ramps_Kernik_200_50_4_-120_60_500_artefact_True_short.pkl
# The protocol is 9055.950603217367 ms
# --- 20.682597875595093 seconds ---

# %%
'''
Hodgkin Huxley 1592d
'''
model_path = "./mmt-model-files/hh-1952d-modern.mmt"  
start_time = time.time()
model = Simulator(model_path) 
model.name = "Hodgkin Huxley 1592d"
times = np.linspace(0,60,1000)
d = model.simulate(times=times, pre_sim=0)    
plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=model.name, figsize=(6,4))
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 11.008200407028198 seconds ---

# %%
'''
Beeler and Reuter 1977
'''
model_path = "./mmt-model-files/br-1977.mmt" 
start_time = time.time()
model = Simulator(model_path) 
model.name = "Beeler and Reuter 1977"
times = np.linspace(0,2000,5000)
d = model.simulate(times)    
plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=model.name, figsize=(6,4))
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 10.647915840148926 seconds ---

# %%
'''
Kernik 2019
'''
model_path = "./mmt-model-files/kernik-2019.mmt" 
start_time = time.time()
model = Simulator(model_path) 
model.name = "Kernik 2019"
times = np.linspace(0,2000,10000)
d = model.simulate(times)    
plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=model.name, figsize=(6,4))
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-03134449f5d4> in <module>
#       4 model_path = "./mmt-model-files/kernik-2019.mmt"
#       5 start_time = time.time()
# ----> 6 model = Simulator(model_path)
#       7 model.name = "Kernik 2019"
#       8 times = np.linspace(0,2000,10000)
#
# D:\Asan\Codes\Electrophysiology\Myokit\simulator_myokit.py in __init__(self, model_path, protocol_def, vhold)
#      26         self.times = np.linspace(0, self.bcl, 1000)  # np.arange(self._bcl)
#      27         # Get model
# ---> 28         self.model, self._protocol, self._script = myokit.load(model_path)
#      29
#      30         self.pacing_constant_pre_simulate(self.vhold)
#
# C:\Anaconda3\envs\ml\lib\site-packages\myokit\_aux.py in load(filename)
#     531     f = open(_examplify(filename), 'r')
#     532     try:
# --> 533         return myokit.parse(f)
#     534     finally:
#     535         f.close()
#
# C:\Anaconda3\envs\ml\lib\site-packages\myokit\_parsing.py in parse(source)
#      40
#      41     # Create tokenizer
# ---> 42     stream = Tokenizer(raw)
#      43
#      44     # Start parsing
#
# C:\Anaconda3\envs\ml\lib\site-packages\myokit\_parsing.py in __init__(self, stream_of_lines, check_indenting)
#    1318
#    1319         # Grab first token
# -> 1320         self._advance()
#    1321
#    1322     #def __iter__(self):
#
# C:\Anaconda3\envs\ml\lib\site-packages\myokit\_parsing.py in _advance(self)
#    1331             c.append(self._next[1])
#    1332         try:
# -> 1333             self._peek = next(self._tokenizer)
#    1334             while self._peek[0] == WHITESPACE:
#    1335                 for c in self._catchers.values():
#
# C:\Anaconda3\envs\ml\lib\site-packages\myokit\_parsing.py in _tizer(self, stream, check_indenting)
#    1413         numb = 0
#    1414         ln = 0
# -> 1415         for line in stream:
#    1416
#    1417             # First line number is 1
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xe2 in position 619: illegal multibyte sequence

# %%
'''
Tentusscher 2006
'''
model_path = "./mmt-model-files/tentusscher-2006.mmt" 

start_time = time.time()
model = Simulator(model_path) 
model.name = "Tentusscher 2006"
times = np.linspace(0,2000,10000)
d = model.simulate(times)    
plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=model.name, figsize=(6,4))
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 11.256816864013672 seconds ---

# %%
'''
O'Hara-Rudy 2017
'''
model_path = "./mmt-model-files/ord-2017.mmt" 
cells = {
    'Endocardial' : 0,
    'Epicardial' : 1,
    'Mid-myocardial' : 2,
}
start_time = time.time()
model = Simulator(model_path) 
model.name = "O'Hara-Rudy 2017"
times = np.linspace(0,500,1000)
model.bcl = 1000
for name, mode in cells.items():    
    model.simulation.set_constant('cell.mode', mode)    
    d = model.simulate(times, pre_sim=1)        
    plot_cell.plot_1D( d['engine.time'], d['membrane.V'], title=model.name+' '+name, figsize=(6,4))
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 16.570999145507812 seconds ---

# %%
sys.path.append('./Protocols')
from protocols import leak_staircase
'''
Kylie 2017 IKr
'''
model_path = "./mmt-model-files/kylie-2017-IKr.mmt" 

start_time = time.time()
simulator = Simulator(model_path, leak_staircase, vhold=-80e-3) 
simulator.name = "Kylie 2017 IKr"
times = np.linspace(0, 15.4, 1000)
# simulator.pacing_constant_pre_simulate(-80e-3)
d = simulator.simulate(times, extra_log=['ikr.IKr', 'ikr.open', 'ikr.active'], pre_sim=2)    
population_by_continent = {
    'O': d['ikr.open']*d['ikr.active'],
    'I': d['ikr.open']*(1-d['ikr.active']),
    'C': (1-d['ikr.open'])*d['ikr.active'],
    'IC': (1-d['ikr.open'])*(1-d['ikr.active']),    
}
plot_cell.plot_1D( d['engine.time'], d['membrane.V']*1000, title='Staircase Protocol', figsize=(15,2), xlabel='Time (s)', ylabel='Voltage (mV)', label=None, xlim=(0, times.max()), ylim=None, save_path=None)
plot_cell.plot_1D( d['engine.time'], d['ikr.IKr']*1000, title=None, figsize=(15,2), xlabel='Time (s)', ylabel='Current (pA)', label=None, xlim=(0, times.max()), save_path=None)
plot_cell.plot_stack( d['engine.time'], population_by_continent.values(), labels=population_by_continent.keys(), figsize=(15,2), xlabel='Time (s)', xlim=(0, times.max()), save_path="occupancy.jpg" )
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 10.776829957962036 seconds ---
