# %%
import os, sys, time, copy, math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import multiprocessing
from functools import partial
from tqdm import tqdm

import collections
from typing import List
import bisect
import myokit
sys.path.append('../../../')
sys.path.append('../../../Protocols')
sys.path.append('../../../Models')
sys.path.append('../../../Lib')
import mod_protocols
import protocol_lib
import mod_trace

import simulator_myokit
import simulator_scipy
import vc_protocols

# %%
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)
        print('"%s" has been created.'%(path))
    else:
        print("The folder already exists.")

# %%
def find_closest_index(array, t):
    """Given an array, return the index with the value closest to t."""
    return (np.abs(np.array(array) - t)).argmin()

def get_currents_with_constant_dt(params, x): # avg, min, max
        
    window = params['window']
    step_size = params['step_size']
    window_type = params['window_type']
        
    times = x[0]
    i_ion = x[1]
                      
    i_ion_window = []
    t = 0  
    if window_type == 'avg':
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]                                       
            i_ion_window.append(sum(I_window)/len(I_window))  
            t += step_size     
    if window_type == 'min':
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]                           
            i_ion_window.append(I_window.min())      
            t += step_size
    elif window_type == 'max':    
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1] 
            i_ion_window.append(I_window.max())                                                  
            t += step_size
    elif window_type == 'amax':        
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]       
            I_window_max = I_window.max()
            I_window_min = I_window.min()            
            if abs(I_window_max) > abs(I_window_min):
                i_ion_window.append(I_window_max)                
            else : 
                i_ion_window.append(I_window_min)                                        
            t += step_size
    elif window_type == 'avg_min':
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]                   
            i_ion_window.append([sum(I_window)/len(I_window), I_window.min()])                        
            t += step_size    
    elif window_type == 'avg_amax_min':
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]                           
            I_window_amax = None
            I_window_max = I_window.max()
            I_window_min = I_window.min()
            if abs(I_window_max) > abs(I_window_min):
                I_window_amax = I_window_max
            else : 
                I_window_amax = I_window_min                            
            i_ion_window.append([sum(I_window)/len(I_window), I_window_amax, I_window_min])                        
            t += step_size    
    elif window_type == 'all':
        while t <= times[-1] - window:
            start_index = find_closest_index(times, t)
            end_index = find_closest_index(times, t + window)            
            I_window = i_ion[start_index: end_index + 1]       
            I_window_amax = None
            I_window_max = I_window.max()
            I_window_min = I_window.min()
            if abs(I_window_max) > abs(I_window_min):
                I_window_amax = I_window_max
            else : 
                I_window_amax = I_window_min                            
            i_ion_window.append([sum(I_window)/len(I_window), I_window_amax, I_window_min, I_window_max])                        
            t += step_size
            
    return i_ion_window

# %%
# V = model.voltage(times)
g = 0.1524 * 1e3 # [pA/V]
p1 = 2.26e-4 * 1e3 # [1/s]
p2 = 0.0699 * 1e3  # [1/V]
p3 = 3.45e-5 * 1e3 # [1/s]
p4 = 0.05462 * 1e3 # [1/V]
p5 = 0.0873 * 1e3  # [1/s]
p6 = 8.91e-3 * 1e3 # [1/V]
p7 = 5.15e-3 * 1e3 # [1/s]
p8 = 0.03158 * 1e3 # [1/V]

dt = 0.0002
t_eval = np.arange(77000)*dt  # times = np.linspace(0, 15.4, 77000)
t_span = (0, t_eval.max())
t_span
# Out:
# (0, 15.3998)

# %% [markdown]
# ### Voltage protocol (leak_staircase)

# %%
# VC_protocol = vc_protocols_for_myokit.leak_staircase()
VC_protocol = vc_protocols.leak_staircase()

print(f'The protocol is {VC_protocol.get_voltage_change_endpoints()[-1]} s')
VC_protocol.plot_voltage_clamp_protocol(t_eval)
# Out:
# The protocol is 15.4 s

# %%
gen_params = {
    'end_time': VC_protocol.get_voltage_change_endpoints()[-1],   
    't_eval' : t_eval, 
    'log_li' : ['ikr.IKr', 'ikr.open', 'ikr.active'],
    'save_log_li' : ['ikr.IKr'],
    'nData' : 5,                             
    'dataset_dir' : f'../../../../Dataset/herg25oc1_real_data',
    'data_file_name' : 'IKr',
    'window' : 0.01,
    'step_size' : 0.01,
    'window_type' : 'amax'
}  
# gen_params['dataset_dir'] = gen_params['dataset_dir'] + f"_w{gen_params['window']}_s{gen_params['step_size']}"
print( gen_params['dataset_dir'] )

sys.path.append(gen_params['dataset_dir'])
from getdata import get_dataset, get_times
# Out:
# ../../../../Dataset/herg25oc1_real_data

# %% [markdown]
# ### Get voltages

# %%
voltages = np.array(VC_protocol.get_voltage_clamp_protocol(gen_params['t_eval']))*1000

# %% [markdown]
# ### Get experimental dataset

# %%
# for i in range(5):
# xs, ys = get_dataset(file_numbers=range(1, 3), multi=True, use_torch=True)

# xs, ys = get_dataset(file_numbers=range(1, 31), window=10, step_size=5, multi=False, use_torch=False, get_raw=False)

cell_to_remove=['A04', 'A15', 'E05', 'E22', 'G10', 'G22', 'H08', 'I10', 'I12', 'I16', 'L08', 'P15', 'P18' ] # M24
cell_to_remove=[]

xs, ys, cells = get_dataset(cell_to_remove=cell_to_remove, scale=1, multi=True, torch_tensor=False)  # <-- fast
times = get_times(scale=1)
# Out:
# The number of full cells : 211
# The number of removed Cells : 0
# The number of cells : 211

# %%
print(xs.shape, ys.shape)
# Out:
# (211, 77000) (211, 9)

# %% [markdown]
# ### Simulation setting

# %%
start_time = time.time()

# hERG model settings
temperature = 25.0
temperature += 273.15  # in K
fit_seed = '542811797'
withfcap = False

model, p, s = myokit.load("../../../mmt-model-files/kylie-2017-IKr.mmt")    
model.get('phys.T').set_rhs(temperature)
# Set concentration
model.get('potassium.Ko').set_rhs(float(4.0))
model.get('potassium.Ki').set_rhs(float(110.0))

sim = simulator_myokit.Simulator(model, VC_protocol, max_step=dt, abs_tol=1e-12, rel_tol=1e-14, vhold=-80e-3)  # 1e-12, 1e-14  # 1e-08, 1e-10
sim.name = "kylie2017IKr"  

print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 1.7261059284210205 seconds ---

# %% [markdown]
# ### Check std of noise for experimental data

# %%
check_range = 100

std_li = []
for x in xs:    
    std_li.append(np.std(x[:check_range]))
std_li = np.array(std_li)
std_avg = std_li.mean()
std_min = std_li.min()
std_max = std_li.max()
std_argmax = std_li.argmax()
std_argmin = std_li.argmin()
print(f"min: {std_min}  |  max: {std_max}  |  avg: {std_avg}")
# Out:
# min: 8.346994151712211  |  max: 14.15013773648413  |  avg: 10.50049650793822

# %%
# VC_protocol.get_voltage_change_endpoints()

# %% [markdown]
# ### modify experimental current

# %%
def get_modified_current( params, current ):  
    
    times = params['time']
    vc_protocol = params['vc']    
    neighbor_radius = params['neighbor_radius']
    
    method = params['method']
         
    pre_step = vc_protocol.steps[0]
    pre_step_index = 0
    modified_current = copy.copy(current)
    
       
    for i, t in enumerate(times):
        """Gets the voltage based on provided steps for the specified time."""
        # pre_V = VC_protocol.get_voltage_at_time(times[i-1])
        V = VC_protocol.get_voltage_at_time(t)
                        
        step_index = bisect.bisect_left( vc_protocol.get_voltage_change_endpoints(), t )
        current_step = vc_protocol.steps[step_index]
        if (pre_step_index != step_index) :
                        
            neighboring_value = current[i-10:i-1].mean()
                
            if method == 0:
                modified_current[i] = neighboring_value                    
                for j in range(1, neighbor_radius+1):
                    left_neighbor_index = i - j 
                    right_neighbor_index = i + j                 
                    modified_current[left_neighbor_index] = neighboring_value                                    
                    modified_current[right_neighbor_index] = neighboring_value                    
            elif method == 1:
                if V - VC_protocol.get_voltage_at_time(times[i-1]) > 0 :
                    for j in range( 2*neighbor_radius+1):
                        neighbor_index = i - neighbor_radius + j                     
                        if (current[neighbor_index] - neighboring_value) < -10:
                            modified_current[neighbor_index] = neighboring_value                                    
                elif V - VC_protocol.get_voltage_at_time(times[i-1]) < 0 :
                    for j in range( 2*neighbor_radius+1):
                        neighbor_index = i - neighbor_radius + j                     
                        if (current[neighbor_index] - neighboring_value) > 10:
                            modified_current[neighbor_index] = neighboring_value  

            pre_step_index = step_index
            pre_step = current_step
            
    return modified_current

# %%
times_vc_params = {
    'time' : times,
    'vc' : VC_protocol,
    'neighbor_radius' : 5,
    'method' : 1
}

get_modified_current(times_vc_params, xs[0])
# Out:
# array([-17.55719485,  15.51956915,  24.97007315, ...,   4.49398115,
#        -15.98211085,   4.49398115])

# %%
start_time = time.time()

pool = multiprocessing.Pool(processes=os.cpu_count())
func = partial(get_modified_current, times_vc_params)
modified_currents = pool.map(func, xs)
pool.close()
pool.join()

print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 9.917547225952148 seconds ---

# %%
modified_currents = np.array(modified_currents)
modified_currents.shape
# Out:
# (211, 77000)

# %%
def fast_fourier_transform(times, data, topn=100, fs = 5000, is_plot=True):
    # fs = fs # max 500Hz *2  
    dt = 0.0002 # 1/fs   # 0.001  

    newt = times
    newx = data 

    # 주파수 생성  
    nfft = len(newt)  # number of sample count.  
    print('nfft = ', nfft)  
    df = fs/nfft    # 주파수 증가량 = max freq / 샘플개수  
    k = np.arange(nfft)  
    f = k*df      # 0부터~최대주파수까지의 범위 (sample count 개수 만큼, df증가량으로 분포)  

    # 주파수 스펙트럼은 중앙을 기준으로 대칭이 된다. 반만 구한다.  
    nfft_half = math.trunc(nfft/2)  
    f0 = f[range(nfft_half)]      # only half size check for get hz.  
    y = np.fft.fft(newx)/nfft * 2 # 증폭을 두 배로 한다. (반만 계산해서 에너지가 반으로 줌)  
    y0 = y[range(nfft_half)]       # one side.  
    amp = abs(y0)  # 벡터(복소수) norm 측정. 신호 강도. 
    print(amp.shape)
    if is_plot:  
        plt.figure()  
        plt.plot(f0, amp)  
        # plt.savefig('fft02_3.jpg')  
        # plt.xlim(0, 10)
        # plt.ylim(0,2)
        plt.show()    
        
    idxy = np.argsort(-amp) 
    # recover      
    newy = np.zeros((nfft,))  
    arfreq = []  
    arcoec = []  
    arcoes = []  
    for i in range(topn):  
        freq = f0[idxy[i]]  
        yx = y[idxy[i]]  
        coec = yx.real  
        coes = yx.imag * -1
        # print('freq=', freq, 'coec=', coec, ' coes', coes)  
        # newy += coec * np.cos( 2*np.pi*freq*newt+ang) + coes * np.sin( 2*np.pi*freq*newt+ang)  
        newy += coec * np.cos(2 * np.pi * freq * newt) + coes * np.sin(2 * np.pi * freq * newt) 
        arfreq.append(freq)  
        arcoec.append(coec)  
        arcoes.append(coes)  
                               
    return newy

# %%
test_index = 0

print(f"Cell : {cells[test_index]}")
test_raw = xs[test_index]
test_modified = modified_currents[test_index]


model_params = {                    
    'ikr.g' : ys[test_index, 0],  # random.uniform(parameter_ranges[0][0], parameter_ranges[0][1]),
    'ikr.p1' : ys[test_index, 1],
    'ikr.p2' : ys[test_index, 2],
    'ikr.p3' : ys[test_index, 3],
    'ikr.p4' : ys[test_index, 4],
    'ikr.p5' : ys[test_index, 5],
    'ikr.p6' : ys[test_index, 6],
    'ikr.p7' : ys[test_index, 7],
    'ikr.p8' : ys[test_index, 8],                
} 
sim.set_simulation_params(model_params)                

sim.pre_simulate(100, sim_type=1)
d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])                           

sim_result= {}
sim_result["time"] = d['engine.time']
sim_result["IKr"] = d['ikr.IKr'] # + np.random.normal(0, std_avg , d['ikr.IKr'].shape) # add noise
sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
sim_result["open"] = d['ikr.open']
sim_result["active"] = d['ikr.open']
# sim_result["params"] = raw['params']
    
    
topn = 100
is_plot = False

newy_raw = fast_fourier_transform(times, test_raw, topn=topn, is_plot=is_plot)

newy_modified = fast_fourier_transform(times, test_modified, topn=topn, is_plot=is_plot)

newy_sim = fast_fourier_transform(sim_result["time"], sim_result["IKr"], topn=topn, is_plot=is_plot)
# Out:
# Cell : A01
# nfft =  77000
# (38500,)
# nfft =  77000
# (38500,)
# nfft =  77000
# (38500,)

# %%
fig, ax = plt.subplots(1,1, figsize=(30,20))     
# ax.set_xlabel('Time (ms)')       
# ax.set_ylabel(f'IKr')      
# ax.plot(times, test_real  , c='k', label='orginal')  
ax.plot(times, newy_raw, c='k', label='fft_raw', linewidth=7)  
ax.plot(times, newy_modified, c='y', label='fft_modified', linewidth=4)  
ax.plot(sim_result["time"], newy_sim, c='r', label='fft_sim', linewidth=1)  
ax.legend()
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(30,20))     
# ax.set_xlabel('Time (ms)')       
# ax.set_ylabel(f'IKr')      
ax.plot(times, test_raw  , c='k', label='orginal', linewidth=7)  
ax.plot(times, test_modified, c='y', label='modified', linewidth=4)  
ax.plot(sim_result["time"], sim_result["IKr"], c='r', label='sim', linewidth=1)  
ax.legend()
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(30,20))     
# ax.set_xlabel('Time (ms)')       
# ax.set_ylabel(f'IKr')      
# ax.plot(times, test_raw  , c='k', label='orginal', linewidth=7)  
ax.plot(sim_result["time"], newy_sim, c='k', label='fft_sim', linewidth=5)  
ax.plot(sim_result["time"], sim_result["IKr"], c='r', label='sim', linewidth=2)  
ax.legend()
ax.grid()
plt.show()

# %%
# # outlier 찾기. 사분위수 사용. boxplot.  
# ampsort = np.sort(amp)  
# q1, q3 = np.percentile(ampsort, [27, 73])  
# iqr = q3-q1  
# upper_bound = q3+1.5*iqr  
# print('q1=',q1, 'q3=',q3, 'upper_bound=', upper_bound)  
# outer = ampsort[ampsort>upper_bound]  
# print('outer cnt=', len(outer))  
# topn = len(outer)  

# # print(outer)

# %% [markdown]
# ### Create a folder for results

# %%
dir_name = f"./modified_experimental_data_type{times_vc_params['method']}_w{gen_params['window']}_s{gen_params['step_size']}_{gen_params['window_type']}"
print(dir_name)
create_folder(dir_name)
# Out:
# ./modified_experimental_data_type1_w0.01_s0.01_amax
# The folder already exists.

# %% [markdown]
# ### Save and show results

# %%
def show_results(is_plot=True, index=0):
        
    raw = {}
    raw['time'] = times
    raw['IKr'] = xs[index]
    raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
    raw['params'] = ys[index]
    # print(np.array(raw['window']).shape)
    modified = {}
    modified['time'] = times
    modified['IKr'] = modified_currents[index]
    modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
        
    model_params = {                    
        'ikr.g' : raw['params'][0],  # random.uniform(parameter_ranges[0][0], parameter_ranges[0][1]),
        'ikr.p1' : raw['params'][1],
        'ikr.p2' : raw['params'][2],
        'ikr.p3' : raw['params'][3],
        'ikr.p4' : raw['params'][4],
        'ikr.p5' : raw['params'][5],
        'ikr.p6' : raw['params'][6],
        'ikr.p7' : raw['params'][7],
        'ikr.p8' : raw['params'][8],                
    } 
    sim.set_simulation_params(model_params)                

    sim.pre_simulate(100, sim_type=1)
    d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])                           
    
    sim_result= {}
    sim_result["time"] = d['engine.time']
    sim_result["IKr"] = d['ikr.IKr'] # + np.random.normal(0, std_avg , d['ikr.IKr'].shape) # add noise
    sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
    sim_result["open"] = d['ikr.open']
    sim_result["active"] = d['ikr.open']
    sim_result["params"] = raw['params']
    
    fig, ax = plt.subplots(3,1, figsize=(20,10))    
    # fig.suptitle(sim.name, fontsize=14)
    # if name!='Time Start' and name!='Time End' and name!='Time Mid':
    # ax.set_title('Simulation %d'%(simulationNo))    
    # ax.set_ylim(ylim[0], ylim[1])
    
    ax[0].set_xlabel('Time (ms)')       
    ax[0].set_ylabel(f'Voltage')      
    ax[0].plot( times, voltages, label='VC', color='k')
    
    ax[1].set_xlabel('Time (ms)')       
    ax[1].set_ylabel(f'IKr')      
    ax[1].plot( raw['time'], raw['IKr'], label='raw', color='k', linewidth=5)         
    ax[1].plot( modified['time'], modified['IKr'], label='modified', color='y', linewidth=3)         
    ax[1].plot( sim_result['time'], sim_result['IKr'], label='sim', color='r', linewidth=1)
    ax[1].legend()
    ax[1].grid()
    
    # ax[2].set_xlabel('Time (ms)')       
    ax[2].set_ylabel(f'IKr')      
    ax[2].plot(  raw['window'], label='raw', color='k', linewidth=5)         
    ax[2].plot(  modified['window'], label='modified', color='y', linewidth=3)         
    ax[2].plot(  sim_result['window'], label='sim', color='r', linewidth=1)
    ax[2].legend()
    ax[2].grid()
    
    xrange = (0.895, 0.9)
    # ax[0].set_xlim(xrange[1]-0.0002, xrange[1]+0.0002*50)
    # ax[1].set_xlim(xrange[1]-0.0002, xrange[1]+0.0002*50)
    # ax[-1].set_ylim(-5, 5)
    plt.subplots_adjust(left=0.07, bottom=0.1, right=0.95, top=0.95, wspace=0.5, hspace=0.04)
    
    if is_plot:
        plt.show()
    else:
        fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)

# %%
start_time = time.time()

for i in np.arange(1) : #np.random.randint(0, len(modified_current), size=5 ) # [1, 3, 4, 5, 6, 7]:    
    show_results(is_plot=True, index=i)    
    
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 3.5270726680755615 seconds ---

# %%
# start_time = time.time()

# save_indices = np.arange(211) #np.random.randint(0, len(modified_current), size=5 ) # [1, 3, 4, 5, 6, 7]

# pool = multiprocessing.Pool(processes=os.cpu_count())
# func = partial(show_results, False)
# pool.map(func, save_indices)
# pool.close()
# pool.join()

# print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-175:
# Process ForkPoolWorker-180:
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-164:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-177:
# Process ForkPoolWorker-179:
# Process ForkPoolWorker-152:
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-111:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-142:
# Process ForkPoolWorker-145:
# Process ForkPoolWorker-169:
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-151:
# Process ForkPoolWorker-171:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-131:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-112:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-143:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-116:
# Process ForkPoolWorker-168:
# Process ForkPoolWorker-140:
# Process ForkPoolWorker-139:
# Process ForkPoolWorker-150:
# Process ForkPoolWorker-159:
# Process ForkPoolWorker-174:
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-147:
# Process ForkPoolWorker-160:
# Process ForkPoolWorker-162:
# Process ForkPoolWorker-141:
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-144:
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-138:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-154:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-132:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-172:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-176:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-170:
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-122:
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-125:
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-149:
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_1896013/2598303503.py", line 28, in show_results
#     d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 28, in show_results
#     d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 41, in get_currents_with_constant_dt
#     I_window = i_ion[start_index: end_index + 1]
#   File "/tmp/ipykernel_1896013/2598303503.py", line 28, in show_results
#     d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/2598303503.py", line 38, in show_results
#     fig, ax = plt.subplots(3,1, figsize=(20,10))
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 42, in get_currents_with_constant_dt
#     I_window_max = I_window.max()
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 38, in show_results
#     fig, ax = plt.subplots(3,1, figsize=(20,10))
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 28, in show_results
#     d = sim.simulate( gen_params['end_time'], log_times=gen_params['t_eval'], extra_log=gen_params['log_li'])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 38, in get_currents_with_constant_dt
#     while t <= times[-1] - window:
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 12, in show_results
#     modified['window'] = get_currents_with_constant_dt(gen_params, [times, modified_currents[index]])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 43, in get_currents_with_constant_dt
#     I_window_min = I_window.min()
#   File "/tmp/ipykernel_1896013/2598303503.py", line 6, in show_results
#     raw['window'] = get_currents_with_constant_dt(gen_params, [times, xs[index]])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "../../../simulator_myokit.py", line 147, in simulate
#     log = ['engine.time', 'membrane.V'] + extra_log,
#   File "/tmp/ipykernel_1896013/2598303503.py", line 33, in show_results
#     sim_result["window"] = get_currents_with_constant_dt(gen_params, [d['engine.time'], d['ikr.IKr']])
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 38, in show_results
#     fig, ax = plt.subplots(3,1, figsize=(20,10))
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
# Process ForkPoolWorker-137:
#   File "../../../simulator_myokit.py", line 147, in simulate
#     log = ['engine.time', 'membrane.V'] + extra_log,
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 43, in get_currents_with_constant_dt
#     I_window_min = I_window.min()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 42, in get_currents_with_constant_dt
#     I_window_max = I_window.max()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "../../../simulator_myokit.py", line 147, in simulate
#     log = ['engine.time', 'membrane.V'] + extra_log,
# KeyboardInterrupt
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py", line 1437, in subplots
#     gridspec_kw=gridspec_kw)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/2598303503.py", line 73, in show_results
#     fig.savefig(os.path.join(dir_name, f"{cells[index]}.jpg"), dpi=100)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py", line 40, in _amax
#     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py", line 1437, in subplots
#     gridspec_kw=gridspec_kw)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "../../../simulator_myokit.py", line 157, in simulate
#     current_timestep.append(mod_trace.Current(name=name.split('.')[1], value=d[name][i]))
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
# KeyboardInterrupt
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py", line 44, in _amin
#     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 40, in get_currents_with_constant_dt
#     end_index = find_closest_index(times, t + window)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/site-packages/myokit/_sim/cvodessim.py", line 483, in run
#     apd_variable, apd_threshold, progress, msg)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 39, in get_currents_with_constant_dt
#     start_index = find_closest_index(times, t)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py", line 1437, in subplots
#     gridspec_kw=gridspec_kw)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/myokit/_sim/cvodessim.py", line 483, in run
#     apd_variable, apd_threshold, progress, msg)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py", line 44, in _amin
#     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py", line 40, in _amax
#     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 3019, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/conda/lib/python3.7/site-packages/myokit/_sim/cvodessim.py", line 483, in run
#     apd_variable, apd_threshold, progress, msg)
#   File "/tmp/ipykernel_1896013/3474845984.py", line 3, in find_closest_index
#     return (np.abs(np.array(array) - t)).argmin()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.7/site-packages/matplotlib/figure.py", line 898, in subplots
#     subplot_kw=subplot_kw)
# KeyboardInterrupt
